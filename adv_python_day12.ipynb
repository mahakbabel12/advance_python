# %%
import pandas as pd

# %%
df =pd.read_csv("placement.csv")

# %%
df.values    #in array format without column name
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df_values = df.values

# %%
df_new = pd.DataFrame(df_values , columns = ['new_cgpa' , 'updated_resume','placed'])

# %%
df_new
# Out:
#     new_cgpa  updated_resume  placed
# 0       8.14            6.52     1.0
# 1       6.17            5.17     0.0
# 2       8.27            8.86     1.0
# 3       6.88            7.27     1.0
# 4       7.52            7.30     1.0
# ..       ...             ...     ...
# 95      6.33            6.38     0.0
# 96      8.23            7.76     1.0
# 97      6.65            7.78     0.0
# 98      8.14            5.63     1.0
# 99      6.09            6.61     0.0
#
# [100 rows x 3 columns]

# %%
#second method

# %%
df.values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df_new2 = pd.DataFrame(df.values , columns = df.columns)

# %%
df_new2
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52     1.0
# 1   6.17          5.17     0.0
# 2   8.27          8.86     1.0
# 3   6.88          7.27     1.0
# 4   7.52          7.30     1.0
# ..   ...           ...     ...
# 95  6.33          6.38     0.0
# 96  8.23          7.76     1.0
# 97  6.65          7.78     0.0
# 98  8.14          5.63     1.0
# 99  6.09          6.61     0.0
#
# [100 rows x 3 columns]

# %% [markdown]
# # pipeline

# %%
#differnece betwwn column transformer and pipeline?
#both are containerisng 
#but in column transformer ek step ka output dusre ka input nahi bnata h ,
#but in pipeline ek step ka output dusre ka input bnta hai.

# %%
#Data --> separate (categorical ,numerical) ---->
#categorical data --->SimpleImputer fill ----->Encode
#numerical data --->SimpleImputer fill------>Standardize

#Apply === Alogirthm (LogisticRegression)

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler ,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
#Define the columns that need to be processed
categorical_features = ['gender','city']
numeric_features = ['age','fever']

# %%
#create transformers
numeric_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy = 'mean')),
    ('scaler',StandardScaler())
])
categorical_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy = 'most_frequent')),
    ('onehot',OneHotEncoder(handle_unknown = 'ignore'))
])

#combine transformers
preprocessor = ColumnTransformer(
    transformers = [
        ('num',numeric_transformer,numeric_features),
        ('cat',categorical_transformer,categorical_features),
    ])
